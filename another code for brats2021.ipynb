# %%
# !pip install itkwidgets
# Out:
# Requirement already satisfied: itkwidgets in c:\users\hp\anaconda3\lib\site-packages (0.32.2)
# Requirement already satisfied: zstandard in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (0.18.0)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (1.16.0)
# Requirement already satisfied: itk-numerics<5.3,>=5.2.0.post2 in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (5.2.1.post1)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (3.4.3)
# Requirement already satisfied: itk-core<5.3,>=5.2.0.post2 in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (5.2.1.post1)
# Requirement already satisfied: numpy in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (1.20.3)
# Requirement already satisfied: ipywidgets>=7.5.1 in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (7.6.5)
# Requirement already satisfied: itk-filtering<5.3,>=5.2.0.post2 in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (5.2.1.post1)
# Requirement already satisfied: colorcet in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (3.0.0)
# Requirement already satisfied: ipydatawidgets>=4.0.1 in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (4.3.2)
# Requirement already satisfied: itk-meshtopolydata==0.8.1 in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (0.8.1)
# Requirement already satisfied: ipympl>=0.4.1 in c:\users\hp\anaconda3\lib\site-packages (from itkwidgets) (0.9.2)
# Requirement already satisfied: traittypes>=0.2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipydatawidgets>=4.0.1->itkwidgets) (0.2.1)
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (from ipympl>=0.4.1->itkwidgets) (8.4.0)
# Requirement already satisfied: traitlets<6 in c:\users\hp\anaconda3\lib\site-packages (from ipympl>=0.4.1->itkwidgets) (5.1.0)
# Requirement already satisfied: ipython<9 in c:\users\hp\anaconda3\lib\site-packages (from ipympl>=0.4.1->itkwidgets) (7.29.0)
# Requirement already satisfied: ipython-genutils in c:\users\hp\anaconda3\lib\site-packages (from ipympl>=0.4.1->itkwidgets) (0.2.0)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (3.0.20)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (0.4.4)
# Requirement already satisfied: pygments in c:\users\hp\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\hp\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (58.0.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (0.18.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (5.1.0)
# Requirement already satisfied: matplotlib-inline in c:\users\hp\anaconda3\lib\site-packages (from ipython<9->ipympl>=0.4.1->itkwidgets) (0.1.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->itkwidgets) (6.4.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->itkwidgets) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->itkwidgets) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipywidgets>=7.5.1->itkwidgets) (1.0.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->itkwidgets) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->itkwidgets) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->itkwidgets) (1.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9->ipympl>=0.4.1->itkwidgets) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->itkwidgets) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->itkwidgets) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->itkwidgets) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\hp\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.1->itkwidgets) (228)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->itkwidgets) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->itkwidgets) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib->itkwidgets) (1.3.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\hp\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.1->itkwidgets) (3.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->itkwidgets) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\hp\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.1->itkwidgets) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl>=0.4.1->itkwidgets) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\hp\anaconda3\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (6.4.5)
# Requirement already satisfied: jinja2 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (2.11.3)
# Requirement already satisfied: argon2-cffi in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (20.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.8.0)
# Requirement already satisfied: nbconvert in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (6.1.0)
# Requirement already satisfied: prometheus-client in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.11.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.9.4)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\hp\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\hp\anaconda3\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (2.20)
# Requirement already satisfied: param>=1.7.0 in c:\users\hp\anaconda3\lib\site-packages (from colorcet->itkwidgets) (1.12.2)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\hp\anaconda3\lib\site-packages (from colorcet->itkwidgets) (0.4.8)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hp\anaconda3\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.1.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.5.3)
# Requirement already satisfied: testpath in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.5.0)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.3)
# Requirement already satisfied: bleach in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (4.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\anaconda3\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.8.4)
# Requirement already satisfied: async-generator in c:\users\hp\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\hp\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (1.5.1)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (21.0)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.5.1->itkwidgets) (0.5.1)
# WARNING: Error parsing requirements for h5py: 'utf-8' codec can't decode byte 0x9c in position 2: invalid start byte in METADATA file at path: c:\users\hp\anaconda3\lib\site-packages\h5py-3.2.1.dist-info\METADATA

# %%
import numpy as np
import nibabel as nib                                                     
import itk                                                                
import itkwidgets
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
import matplotlib.pyplot as plt
from skimage.util import montage 
from skimage.transform import rotate

# %matplotlib inline
import seaborn as sns

# %%
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers.experimental import preprocessing
import cv2

# %%
image_path = r"D:/DATASET/archive/BraTS2021_Training_Data/BraTS2021_00005/BraTS2021_00005_flair.nii.gz"
image_obj = nib.load(image_path)
type(image_obj)
# Out:
# nibabel.nifti1.Nifti1Image

# %%
image_data = image_obj.get_fdata()
print(type(image_data))
image_data.shape
# Out:
# <class 'numpy.ndarray'>
# (240, 240, 155)

# %%
def visualize_3d(layer):
    plt.figure(figsize=(10, 5))
    plt.imshow(image_data[:, :, layer], cmap='gray');
    plt.axis('off')
    return layer

interact(visualize_3d, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
layer = 50
classes_dict = {
    'Normal': 0.,
    'Edema': 1.,
    'Non-enhancing tumor': 2.,
    'Enhancing tumor': 3. 
}

def visualize_3d_labels(layer):
    mask = nib.load('D:/DATASET/archive/BraTS2021_Training_Data/BraTS2021_00005/BraTS2021_00005_seg.nii.gz').get_fdata()
    plt.imshow(mask[:,:,layer])
    plt.axis('off')
    plt.tight_layout()

interact(visualize_3d_labels, layer=(0, image_data.shape[2] - 1));
# Out:
# interactive(children=(IntSlider(value=77, description='layer', max=154), Output()), _dom_classes=('widget-inte…

# %%
fig, ax1 = plt.subplots(1, 1, figsize = (20,20))
ax1.imshow(rotate(montage(image_data[:,:,:]), 90, resize=True), cmap ='gray')

# %%
# dice loss as defined above for 4 classes
def dice_coef(y_true, y_pred, epsilon=0.00001):
    """
    Dice = (2*|X & Y|)/ (|X|+ |Y|)
         =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
    ref: https://arxiv.org/pdf/1606.04797v1.pdf
    
    """
    axis = (0,1,2,3)
    dice_numerator = 2. * K.sum(y_true * y_pred, axis=axis) + epsilon
    dice_denominator = K.sum(y_true*y_true, axis=axis) + K.sum(y_pred*y_pred, axis=axis) + epsilon
    return K.mean((dice_numerator)/(dice_denominator))


 
# define per class evaluation of dice coef
# inspired by https://github.com/keras-team/keras/issues/9395
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[0,:,:,:,1] * y_pred[0,:,:,:,1]))
    return (2. * intersection) / (K.sum(K.square(y_true[0,:,:,:,1])) + K.sum(K.square(y_pred[0,:,:,:,1])) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[0,:,:,:,2] * y_pred[0,:,:,:,2]))
    return (2. * intersection) / (K.sum(K.square(y_true[0,:,:,:,2])) + K.sum(K.square(y_pred[0,:,:,:,2])) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    intersection = K.sum(K.abs(y_true[0,:,:,:,3] * y_pred[0,:,:,:,3]))
    return (2. * intersection) / (K.sum(K.square(y_true[0,:,:,:,3])) + K.sum(K.square(y_pred[0,:,:,:,3])) + epsilon)



# Computing Precision 
def precision(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + K.epsilon())
        return precision

    
# Computing Sensitivity      
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
IMG_SIZE=128

# %%
TRAIN_DATASET_PATH = 'D:/DATASET/archive/BraTS2021_Training_Data/'

# %%
VALIDATION_DATASET_PATH = 'D:\DATASET\archive\validation_images'

# %%
import os
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

# %%
def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories); 

    
train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2) 
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3 later
}

# there are 155 slices per volume
# to start at 5 and use 145 slices means we will skip the first 5 and last 5 
VOLUME_SLICES = 128 
VOLUME_START_AT = 22 # first slice of volume that we will include

# %%
keras = tf.compat.v1.keras
Sequence = keras.utils.Sequence

class DataGenerator(Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 128, 128))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))

        
        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii.gz');
            flair = nib.load(data_path).get_fdata()    

            data_path = os.path.join(case_path, f'{i}_t1ce.nii.gz');
            ce = nib.load(data_path).get_fdata()
            
            data_path = os.path.join(case_path, f'{i}_seg.nii.gz');
            seg = nib.load(data_path).get_fdata()
        
            for j in range(VOLUME_SLICES):
             X[j+(VOLUME_SLICES*c),:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

             X[j+(VOLUME_SLICES*c),:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))
             
             
             y[j +VOLUME_SLICES*c,:,:] = cv2.resize(seg[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

        X = X.reshape(1,128,128,128,2)
        y = y.reshape(1,128,128,128)
        # Generate masks
        y[y==4] = 3;
        y = tf.one_hot(y, 4);
        #Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE));
        #Y = np.array(Y).reshape(1,128,128,128)
        return X/np.max(X), y
        
training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
csv_logger = CSVLogger('D:\DATASET\archive\training.log', separator=',', append=False)


callbacks = [keras.callbacks.EarlyStopping(monitor='loss', min_delta=0,
                               patience=2, verbose=1, mode='auto'),
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                              patience=2, min_lr=0.000001, verbose=1),
      keras.callbacks.ModelCheckpoint(filepath = 'D:\DATASET\archive\3D-UNet-2021model_.{epoch:02d}-{val_loss:.6f}.m5',
                             verbose=1, save_best_only=True, save_weights_only = True),
      csv_logger
    ]

# %%
def conv_block(input_mat,num_filters,kernel_size,batch_norm):
  X = Conv3D(num_filters,kernel_size=(kernel_size,kernel_size,kernel_size),strides=(1,1,1),padding='same')(input_mat)
  if batch_norm:
    X = BatchNormalization()(X)
  
  X = Activation('relu')(X)

  X = Conv3D(num_filters,kernel_size=(kernel_size,kernel_size,kernel_size),strides=(1,1,1),padding='same')(X)
  if batch_norm:
    X = BatchNormalization()(X)
  
  X = Activation('relu')(X)
    
  X = add([input_mat,X]);
  
  return X


def Unet_3d(input_img, n_filters = 8, dropout = 0.2, batch_norm = True):

  #c1 = conv_block(input_img,n_filters,3,batch_norm)
  c1 = Conv3D(n_filters,kernel_size = (5,5,5) , strides = (1,1,1) , padding='same')(input_img)
  #c1 = add([c1,input_img])
  
  c2 = Conv3D(n_filters*2,kernel_size = (2,2,2) , strides = (2,2,2) , padding = 'same' )(c1)
  
  c3 = conv_block(c2 , n_filters*2,5,True)
  
  p3 = Conv3D(n_filters*4,kernel_size = (2,2,2) , strides = (2,2,2), padding = 'same')(c3)
  p3 = Dropout(dropout)(p3)
  
  c4 = conv_block(p3, n_filters*4,5,True)
  p4 = Conv3D(n_filters*8,kernel_size = (2,2,2) , strides = (2,2,2) , padding='same')(c4)
  p4 = Dropout(dropout)(p4)
    
  c5 = conv_block(p4, n_filters*8,5,True)
  p6 = Conv3D(n_filters*16,kernel_size = (2,2,2) , strides = (2,2,2) , padding='same')(c5)
  p6 = Dropout(dropout)(p6)
  #c6 = conv_block(p5, n_filters*8,5,True)
  #p6 = Conv3D(n_filters*16,kernel_size = (2,2,2) , strides = (2,2,2) , padding='same')(c6)

  p7 = conv_block(p6,n_filters*16,5,True)
    
  u6 = Conv3DTranspose(n_filters*8, (2,2,2), strides=(2, 2, 2), padding='same')(p7);
  u6 = concatenate([u6,c5]);
  c7 = conv_block(u6,n_filters*16,5,True)
  c7 = Dropout(dropout)(c7)
  u7 = Conv3DTranspose(n_filters*4,(2,2,2),strides = (2,2,2) , padding= 'same')(c7);

  
  u8 = concatenate([u7,c4]);
  c8 = conv_block(u8,n_filters*8,5,True)
  c8 = Dropout(dropout)(c8)
  u9 = Conv3DTranspose(n_filters*2,(2,2,2),strides = (2,2,2) , padding= 'same')(c8);
    
  u9 = concatenate([u9,c3]);
  c9 = conv_block(u9,n_filters*4,5,True)
  c9 = Dropout(dropout)(c9)
  u10 = Conv3DTranspose(n_filters,(2,2,2),strides = (2,2,2) , padding= 'same')(c9);
  
  
  u10 = concatenate([u10,c1]);
  c10 = Conv3D(n_filters*2,kernel_size = (5,5,5),strides = (1,1,1) , padding = 'same')(u10);
  c10 = Dropout(dropout)(c10)
  c10 = add([c10,u10]);
  
  

  #c9 = conv_block(u9,n_filters,3,batch_norm)
  outputs = Conv3D(4, (1,1,1), activation='softmax')(c10)

  model = Model(inputs=input_img, outputs=outputs)

  return model

# %%
input_layer = Input((128,IMG_SIZE, IMG_SIZE, 2))

model1 = Unet_3d(input_layer)
model1.compile(loss="categorical_crossentropy", optimizer=Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4),
                                                                                                                dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, 
                                                                                                                dice_coef_edema ,dice_coef_enhancing] )

model1.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 128, 128, 1  0           []
#                                 28, 2)]
#
#  conv3d_42 (Conv3D)             (None, 128, 128, 12  2008        ['input_3[0][0]']
#                                 8, 8)
#
#  conv3d_43 (Conv3D)             (None, 64, 64, 64,   1040        ['conv3d_42[0][0]']
#                                 16)
#
#  conv3d_44 (Conv3D)             (None, 64, 64, 64,   32016       ['conv3d_43[0][0]']
#                                 16)
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 64,   64         ['conv3d_44[0][0]']
#  ormalization)                  16)
#
#  activation_28 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_28[0][0]']
#                                 16)
#
#  conv3d_45 (Conv3D)             (None, 64, 64, 64,   32016       ['activation_28[0][0]']
#                                 16)
#
#  batch_normalization_29 (BatchN  (None, 64, 64, 64,   64         ['conv3d_45[0][0]']
#  ormalization)                  16)
#
#  activation_29 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_29[0][0]']
#                                 16)
#
#  add_16 (Add)                   (None, 64, 64, 64,   0           ['conv3d_43[0][0]',
#                                 16)                               'activation_29[0][0]']
#
#  conv3d_46 (Conv3D)             (None, 32, 32, 32,   4128        ['add_16[0][0]']
#                                 32)
#
#  dropout_14 (Dropout)           (None, 32, 32, 32,   0           ['conv3d_46[0][0]']
#                                 32)
#
#  conv3d_47 (Conv3D)             (None, 32, 32, 32,   128032      ['dropout_14[0][0]']
#                                 32)
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 32,   128        ['conv3d_47[0][0]']
#  ormalization)                  32)
#
#  activation_30 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_30[0][0]']
#                                 32)
#
#  conv3d_48 (Conv3D)             (None, 32, 32, 32,   128032      ['activation_30[0][0]']
#                                 32)
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 32,   128        ['conv3d_48[0][0]']
#  ormalization)                  32)
#
#  activation_31 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_31[0][0]']
#                                 32)
#
#  add_17 (Add)                   (None, 32, 32, 32,   0           ['dropout_14[0][0]',
#                                 32)                               'activation_31[0][0]']
#
#  conv3d_49 (Conv3D)             (None, 16, 16, 16,   16448       ['add_17[0][0]']
#                                 64)
#
#  dropout_15 (Dropout)           (None, 16, 16, 16,   0           ['conv3d_49[0][0]']
#                                 64)
#
#  conv3d_50 (Conv3D)             (None, 16, 16, 16,   512064      ['dropout_15[0][0]']
#                                 64)
#
#  batch_normalization_32 (BatchN  (None, 16, 16, 16,   256        ['conv3d_50[0][0]']
#  ormalization)                  64)
#
#  activation_32 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_32[0][0]']
#                                 64)
#
#  conv3d_51 (Conv3D)             (None, 16, 16, 16,   512064      ['activation_32[0][0]']
#                                 64)
#
#  batch_normalization_33 (BatchN  (None, 16, 16, 16,   256        ['conv3d_51[0][0]']
#  ormalization)                  64)
#
#  activation_33 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_33[0][0]']
#                                 64)
#
#  add_18 (Add)                   (None, 16, 16, 16,   0           ['dropout_15[0][0]',
#                                 64)                               'activation_33[0][0]']
#
#  conv3d_52 (Conv3D)             (None, 8, 8, 8, 128  65664       ['add_18[0][0]']
#                                 )
#
#  dropout_16 (Dropout)           (None, 8, 8, 8, 128  0           ['conv3d_52[0][0]']
#                                 )
#
#  conv3d_53 (Conv3D)             (None, 8, 8, 8, 128  2048128     ['dropout_16[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 8, 8, 8, 128  512        ['conv3d_53[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 8, 8, 8, 128  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv3d_54 (Conv3D)             (None, 8, 8, 8, 128  2048128     ['activation_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 8, 8, 8, 128  512        ['conv3d_54[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 8, 8, 8, 128  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  add_19 (Add)                   (None, 8, 8, 8, 128  0           ['dropout_16[0][0]',
#                                 )                                 'activation_35[0][0]']
#
#  conv3d_transpose_8 (Conv3DTran  (None, 16, 16, 16,   65600      ['add_19[0][0]']
#  spose)                         64)
#
#  concatenate_8 (Concatenate)    (None, 16, 16, 16,   0           ['conv3d_transpose_8[0][0]',
#                                 128)                              'add_18[0][0]']
#
#  conv3d_55 (Conv3D)             (None, 16, 16, 16,   2048128     ['concatenate_8[0][0]']
#                                 128)
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 16,   512        ['conv3d_55[0][0]']
#  ormalization)                  128)
#
#  activation_36 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_36[0][0]']
#                                 128)
#
#  conv3d_56 (Conv3D)             (None, 16, 16, 16,   2048128     ['activation_36[0][0]']
#                                 128)
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 16,   512        ['conv3d_56[0][0]']
#  ormalization)                  128)
#
#  activation_37 (Activation)     (None, 16, 16, 16,   0           ['batch_normalization_37[0][0]']
#                                 128)
#
#  add_20 (Add)                   (None, 16, 16, 16,   0           ['concatenate_8[0][0]',
#                                 128)                              'activation_37[0][0]']
#
#  dropout_17 (Dropout)           (None, 16, 16, 16,   0           ['add_20[0][0]']
#                                 128)
#
#  conv3d_transpose_9 (Conv3DTran  (None, 32, 32, 32,   32800      ['dropout_17[0][0]']
#  spose)                         32)
#
#  concatenate_9 (Concatenate)    (None, 32, 32, 32,   0           ['conv3d_transpose_9[0][0]',
#                                 64)                               'add_17[0][0]']
#
#  conv3d_57 (Conv3D)             (None, 32, 32, 32,   512064      ['concatenate_9[0][0]']
#                                 64)
#
#  batch_normalization_38 (BatchN  (None, 32, 32, 32,   256        ['conv3d_57[0][0]']
#  ormalization)                  64)
#
#  activation_38 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_38[0][0]']
#                                 64)
#
#  conv3d_58 (Conv3D)             (None, 32, 32, 32,   512064      ['activation_38[0][0]']
#                                 64)
#
#  batch_normalization_39 (BatchN  (None, 32, 32, 32,   256        ['conv3d_58[0][0]']
#  ormalization)                  64)
#
#  activation_39 (Activation)     (None, 32, 32, 32,   0           ['batch_normalization_39[0][0]']
#                                 64)
#
#  add_21 (Add)                   (None, 32, 32, 32,   0           ['concatenate_9[0][0]',
#                                 64)                               'activation_39[0][0]']
#
#  dropout_18 (Dropout)           (None, 32, 32, 32,   0           ['add_21[0][0]']
#                                 64)
#
#  conv3d_transpose_10 (Conv3DTra  (None, 64, 64, 64,   8208       ['dropout_18[0][0]']
#  nspose)                        16)
#
#  concatenate_10 (Concatenate)   (None, 64, 64, 64,   0           ['conv3d_transpose_10[0][0]',
#                                 32)                               'add_16[0][0]']
#
#  conv3d_59 (Conv3D)             (None, 64, 64, 64,   128032      ['concatenate_10[0][0]']
#                                 32)
#
#  batch_normalization_40 (BatchN  (None, 64, 64, 64,   128        ['conv3d_59[0][0]']
#  ormalization)                  32)
#
#  activation_40 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_40[0][0]']
#                                 32)
#
#  conv3d_60 (Conv3D)             (None, 64, 64, 64,   128032      ['activation_40[0][0]']
#                                 32)
#
#  batch_normalization_41 (BatchN  (None, 64, 64, 64,   128        ['conv3d_60[0][0]']
#  ormalization)                  32)
#
#  activation_41 (Activation)     (None, 64, 64, 64,   0           ['batch_normalization_41[0][0]']
#                                 32)
#
#  add_22 (Add)                   (None, 64, 64, 64,   0           ['concatenate_10[0][0]',
#                                 32)                               'activation_41[0][0]']
#
#  dropout_19 (Dropout)           (None, 64, 64, 64,   0           ['add_22[0][0]']
#                                 32)
#
#  conv3d_transpose_11 (Conv3DTra  (None, 128, 128, 12  2056       ['dropout_19[0][0]']
#  nspose)                        8, 8)
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 12  0           ['conv3d_transpose_11[0][0]',
#                                 8, 16)                            'conv3d_42[0][0]']
#
#  conv3d_61 (Conv3D)             (None, 128, 128, 12  32016       ['concatenate_11[0][0]']
#                                 8, 16)
#
#  dropout_20 (Dropout)           (None, 128, 128, 12  0           ['conv3d_61[0][0]']
#                                 8, 16)
#
#  add_23 (Add)                   (None, 128, 128, 12  0           ['dropout_20[0][0]',
#                                 8, 16)                            'concatenate_11[0][0]']
#
#  conv3d_62 (Conv3D)             (None, 128, 128, 12  68          ['add_23[0][0]']
#                                 8, 4)
#
# ==================================================================================================
# Total params: 11,050,676
# Trainable params: 11,048,820
# Non-trainable params: 1,856
# __________________________________________________________________________________________________

# %%
history =  model1.fit(training_generator,
                     epochs=5,
                     steps_per_epoch=len(train_ids),
                     callbacks= callbacks,
                     validation_data = valid_generator
                     )  
model1.save("D:\DATASET\archive\model_Unet_2mod.h5")
# Out:
# Epoch 1/5
#   7/850 [..............................] - ETA: 8:52:32 - loss: 0.6182 - accuracy: 0.7949 - mean_io_u_2: 0.3750 - dice_coef: 0.2379 - precision: 0.8287 - sensitivity: 0.6316 - specificity: 0.9869 - dice_coef_necrotic: 0.0483 - dice_coef_edema: 0.0594 - dice_coef_enhancing: 0.0230
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19116/2492376909.py in <module>
# ----> 1 history =  model1.fit(training_generator,
#       2                      epochs=5,
#       3                      steps_per_epoch=len(train_ids),
#       4                      callbacks= callbacks,
#       5                      validation_data = valid_generator
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     945       # In this case we have created variables on the first call, so we run the
#     946       # defunned version which is guaranteed to never create variables.
# --> 947       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948     elif self._stateful_fn is not None:
#     949       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
